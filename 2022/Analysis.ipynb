# %% [markdown]
# <a href="https://colab.research.google.com/github/vinayak2019/UK_Bootcamp/blob/main/Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# get the upgraded version of matplotlib 
# !pip install matplotlib --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (3.2.2)
# Collecting matplotlib
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 5.3 MB/s
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 58.5 MB/s
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (7.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: fonttools, matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# Successfully installed fonttools-4.38.0 matplotlib-3.5.3

# %%
# Get data from GitHub
! git clone https://gitHub.com/vinayak2019/UK_Bootcamp.git
# Out:
# Cloning into 'UK_Bootcamp'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 28 (delta 9), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (28/28), done.

# %%
# import pandas and mathplotlib
import pandas as pd
import matplotlib.pyplot as plt

# %%
# create dataframe
df = pd.read_csv("UK_Bootcamp/UK_Bootcamp.csv")
df
# Out:
#            First_Name     Last_Name  \
# 0              Bonnie      Williams
# 1              Mattie  Allen Thomas
# 2               Sarah           NaN
# 3               Tylee   Shackleford
# 4              Thomas      Colliins
# 5              Violet       Newhart
# 6               Chloe         Arpin
# 7       Srinivasa Rao       Hawkins
# 8           Catherine       Quigley
# 9            Sindhura          Yang
# 10                Ben        Sharma
# 11              Angel        Dotsey
# 12             Sourav        Rogers
# 13             Russel    Rockenhaus
# 14              Joyce        Ippili
# 15             Jeremy           NaN
# 16             Sophia        Choate
# 17             Lauren         Rooks
# 18              Great          Rios
# 19          Leighanne        Havard
# 20            Prakhar        Lucido
# 21                NaN          Saha
# 22              Devan        Parris
# 23          A. Gisele      Epperson
# 24               John      Robinson
# 25                Ana      Mitchell
# 26           WITHDREW       Andrews
# 27              Ellen   Wren-Hardin
# 28  Christian Dzidula      Brentzel
# 29             Khamil        Kwenga
# 30           Rosbelly          Yang
# 31               Mary       Sampaio
# 32             Charis      Winstead
# 33              Quinn         Kruse
# 34                Ava        Lyvers
# 35            Katelyn     Wagenheim
# 36             Bailee        Oldham
# 37               Abby       Aguilar
# 38             Sudeys     Tadisetty
# 39               Eric          Mott
# 40            Richard          Audi
# 41             Chavay         Saman
# 42              Helen      Umenweke
#
#                                             Major      Education  \
# 0                                Computer Science  Undergraduate
# 1                            Computer engineering  Undergraduate
# 2                            Chemical Engineering  Undergraduate
# 3                               Civil Engineering  Undergraduate
# 4            Information Communication Technology  Undergraduate
# 5   Pre-engineering at Leestown Middle, 8th grade    High school
# 6                           Biology and Chemistry  Undergraduate
# 7                                         Physics       Graduate
# 8                            Chemical Engineering  Undergraduate
# 9                                    Neuroscience  Undergraduate
# 10                         Mechanical Engineering       Graduate
# 11                                   Neuroscience    High school
# 12                                            NaN    High school
# 13         Biology with a focus in bioinformatics  Undergraduate
# 14                         Biomedical Engineering  Undergraduate
# 15                                      Chemistry       Graduate
# 16                                    Linguistics       Graduate
# 17         Agricultural and Medical Biotechnology  Undergraduate
# 18                          Materials Engineering  Undergraduate
# 19                                        Biology  Undergraduate
# 20                                     Geoscience       Graduate
# 21                                        Geology       Graduate
# 22                                 MBA/Leadership       Graduate
# 23                                        Geology       Graduate
# 24                         Electrical Engineering  Undergraduate
# 25                Political Science and Economics  Undergraduate
# 26                         Biosystems Engineering  Undergraduate
# 27                                      Chemistry       Graduate
# 28                                       Medicine       Graduate
# 29                                      Chemistry       Graduate
# 30                                   Neuroscience  Undergraduate
# 31         Agricultural and Medical Biotechnology  Undergraduate
# 32                                    Linguistics       Graduate
# 33                                    Linguistics       Graduate
# 34         Computer Science, Computer Engineering  Undergraduate
# 35                               Computer Science  Undergraduate
# 36                                            NaN            NaN
# 37                                            NaN            NaN
# 38                            Geological Sciences       Graduate
# 39         Agricultural and Medical Biotechnology  Undergraduate
# 40                                      geologist       Graduate
# 41                                   Neuroscience  Undergraduate
# 42                          Biology and Chemistry  Undergraduate
#
#                                         Is_researcher  \
# 0                                                  No
# 1                                                  No
# 2                                                  No
# 3                                                  No
# 4                                                  No
# 5                                                  No
# 6   Yes - If yes, please describe your research in...
# 7                                                  No
# 8                                                  No
# 9                                                  No
# 10  Yes - If yes, please describe your research in...
# 11                                                 No
# 12                                                 No
# 13  Yes - If yes, please describe your research in...
# 14                                                 No
# 15  Yes - If yes, please describe your research in...
# 16                                                 No
# 17  Yes - If yes, please describe your research in...
# 18  Yes - If yes, please describe your research in...
# 19                                                 No
# 20  Yes - If yes, please describe your research in...
# 21  Yes - If yes, please describe your research in...
# 22                                                 No
# 23  Yes - If yes, please describe your research in...
# 24                                                 No
# 25  Yes - If yes, please describe your research in...
# 26                                                 No
# 27  Yes - If yes, please describe your research in...
# 28                                                 No
# 29  Yes - If yes, please describe your research in...
# 30                                                 No
# 31  Yes - If yes, please describe your research in...
# 32  Yes - If yes, please describe your research in...
# 33  Yes - If yes, please describe your research in...
# 34                                                 No
# 35                                                 No
# 36                                                NaN
# 37                                                NaN
# 38  Yes - If yes, please describe your research in...
# 39                                                 No
# 40  Yes - If yes, please describe your research in...
# 41                                                 No
# 42  Yes - If yes, please describe your research in...
#
#                       Is_programmer
# 0   Yes - If yes, which language(s)
# 1                                No
# 2                                No
# 3   Yes - If yes, which language(s)
# 4   Yes - If yes, which language(s)
# 5   Yes - If yes, which language(s)
# 6                                No
# 7   Yes - If yes, which language(s)
# 8   Yes - If yes, which language(s)
# 9                                No
# 10  Yes - If yes, which language(s)
# 11                               No
# 12                               No
# 13  Yes - If yes, which language(s)
# 14  Yes - If yes, which language(s)
# 15                               No
# 16                               No
# 17                               No
# 18                               No
# 19                               No
# 20  Yes - If yes, which language(s)
# 21  Yes - If yes, which language(s)
# 22                               No
# 23  Yes - If yes, which language(s)
# 24  Yes - If yes, which language(s)
# 25                               No
# 26  Yes - If yes, which language(s)
# 27  Yes - If yes, which language(s)
# 28                               No
# 29                               No
# 30                               No
# 31                               No
# 32                               No
# 33  Yes - If yes, which language(s)
# 34  Yes - If yes, which language(s)
# 35                               No
# 36                              NaN
# 37                              NaN
# 38  Yes - If yes, which language(s)
# 39                               No
# 40  Yes - If yes, which language(s)
# 41                               No
# 42                               No

# %% [markdown]
# # Education

# %%
# This groups data by Education and for each group counts the entries under Education column
education = df.groupby("Education").agg({"Education":"count"})
education
# Out:
#                Education
# Education
# Graduate              15
# High school            3
# Undergraduate         23

# %%
# Get X and Y for bar plot
x_education = education.index.values # The categories
y_education = education["Education"].values # counts

# %%
fig, ax = plt.subplots()
bars = ax.bar(x_education,y_education)
ax.bar_label(bars,padding=5)
ax.set_ylim(0,28)
ax.set_xlabel("Education",fontdict={"weight":"bold","fontsize":12},labelpad=10)
ax.set_ylabel("Count",fontdict={"weight":"bold","fontsize":12},labelpad=10)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Coding experience

# %%
# This groups data by Education and for each group counts the entries under Education column
programmer = df.groupby("Is_programmer").agg({"Is_programmer":"count"})
programmer
# Out:
#                                  Is_programmer
# Is_programmer
# No                                          22
# Yes - If yes, which language(s)             19

# %%
# Get X and Y for bar plot
x_program = programmer.index.values # The categories
y_program = programmer["Is_programmer"].values # counts

# %%
fig, ax = plt.subplots()
bars = ax.bar(x_program,y_program)
ax.bar_label(bars,padding=5)
ax.set_ylim(0,28)
ax.set_xlabel("Coded before",fontdict={"weight":"bold","fontsize":12},labelpad=10)
ax.set_ylabel("Count",fontdict={"weight":"bold","fontsize":12},labelpad=10)
ax.set_xticklabels(["No","Yes"])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   import sys
# [Text(0, 0, 'No'), Text(1, 0, 'Yes')]

# %%
# combined plot
fig, ax = plt.subplots(2,1)
bars = ax[0].bar(x_education,y_education)
ax[0].bar_label(bars,padding=5)
ax[0].set_ylim(0,28)
ax[0].set_xlabel("Education",fontdict={"weight":"bold","fontsize":12},labelpad=10)
ax[0].set_ylabel("Count",fontdict={"weight":"bold","fontsize":12},labelpad=10)

bars = ax[1].bar(x_program,y_program)
ax[1].bar_label(bars,padding=5)
ax[1].set_ylim(0,28)
ax[1].set_xlabel("Coded before",fontdict={"weight":"bold","fontsize":12},labelpad=10)
ax[1].set_ylabel("Count",fontdict={"weight":"bold","fontsize":12},labelpad=10)
ax[1].set_xticklabels(["No","Yes"])
fig.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# #Wordcloud

# %%
# !pip install wordcloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from wordcloud) (3.5.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib->wordcloud) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.15.0)

# %%
from wordcloud import WordCloud

# %%
# Get all major values
majors = df["Major"].dropna().values
majors
# Out:
# array(['Computer Science', 'Computer engineering', 'Chemical Engineering',
#        'Civil Engineering', 'Information Communication Technology',
#        'Pre-engineering at Leestown Middle, 8th grade',
#        'Biology and Chemistry', 'Physics', 'Chemical Engineering',
#        'Neuroscience', 'Mechanical Engineering', 'Neuroscience',
#        'Biology with a focus in bioinformatics', 'Biomedical Engineering',
#        'Chemistry', 'Linguistics',
#        'Agricultural and Medical Biotechnology', 'Materials Engineering',
#        'Biology', 'Geoscience', 'Geology', 'MBA/Leadership', 'Geology',
#        'Electrical Engineering', 'Political Science and Economics',
#        'Biosystems Engineering', 'Chemistry', 'Medicine', 'Chemistry',
#        'Neuroscience', 'Agricultural and Medical Biotechnology',
#        'Linguistics', 'Linguistics',
#        'Computer Science, Computer Engineering', 'Computer Science',
#        'Geological Sciences', 'Agricultural and Medical Biotechnology',
#        'geologist', 'Neuroscience', 'Biology and Chemistry'], dtype=object)

# %%
# combine the word to form text
text = ""

for major in majors:
  text += "_".join(major.strip().split()) + " " # replace space beteen major with _

text
# Out:
# 'Computer_Science Computer_engineering Chemical_Engineering Civil_Engineering Information_Communication_Technology Pre-engineering_at_Leestown_Middle,_8th_grade Biology_and_Chemistry Physics Chemical_Engineering Neuroscience Mechanical_Engineering Neuroscience Biology_with_a_focus_in_bioinformatics Biomedical_Engineering Chemistry Linguistics Agricultural_and_Medical_Biotechnology Materials_Engineering Biology Geoscience Geology MBA/Leadership Geology Electrical_Engineering Political_Science_and_Economics Biosystems_Engineering Chemistry Medicine Chemistry Neuroscience Agricultural_and_Medical_Biotechnology Linguistics Linguistics Computer_Science,_Computer_Engineering Computer_Science Geological_Sciences Agricultural_and_Medical_Biotechnology geologist Neuroscience Biology_and_Chemistry '

# %% [markdown]
# From [documentation](https://amueller.github.io/word_cloud/auto_examples/simple.html)

# %%
wordcloud = WordCloud(background_color="white",repeat=True).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
